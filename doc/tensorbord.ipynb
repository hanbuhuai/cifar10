# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/My Drive/tensorFlow
# !rm -rf ./cifar10
# !git clone https://github.com/hanbuhuai/cifar10.git
# Out:
# /content/gdrive/My Drive/tensorFlow
# Cloning into 'cifar10'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 24 (delta 0), reused 9 (delta 0), pack-reused 15
# Unpacking objects: 100% (24/24), done.
# Checking out files: 100% (15/15), done.

# %%
# %cd /content/gdrive/My Drive/tensorFlow/cifar10
# Out:
# /content/gdrive/My Drive/tensorFlow/cifar10

# %%
# %tensorflow_version 1.x
import tensorflow as tf
tf.__version__
# Out:
# TensorFlow 1.x selected.
# '1.15.2'

# %%
import os
os.kill(os.getpid(), 9)

# %%
# !python3 train.py
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)
# WARNING:tensorflow:From train.py:7: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/tensorFlow/cifar10/vggnet.py:11: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/tensorFlow/cifar10/vggnet.py:22: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/tensorFlow/cifar10/vggnet.py:63: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From train.py:15: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From train.py:16: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From train.py:17: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From train.py:24: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From train.py:25: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:26: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From train.py:29: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:41: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From train.py:48: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-04-20 08:17:54.539245: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-20 08:17:54.587524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.588327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-04-20 08:17:54.588663: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-20 08:17:54.590409: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-20 08:17:54.592150: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-20 08:17:54.592526: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-20 08:17:54.594368: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-20 08:17:54.614665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-20 08:17:54.618417: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-20 08:17:54.618588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.619502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.620228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-20 08:17:54.632624: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-04-20 08:17:54.633040: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1b88a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-20 08:17:54.633100: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-20 08:17:54.715916: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.716858: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1b88bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-20 08:17:54.716899: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-04-20 08:17:54.717928: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.718730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-04-20 08:17:54.718817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-20 08:17:54.718862: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-20 08:17:54.718896: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-20 08:17:54.718946: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-20 08:17:54.718983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-20 08:17:54.719014: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-20 08:17:54.719046: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-20 08:17:54.719178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.719965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.720693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-04-20 08:17:54.724625: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-20 08:17:54.726136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-20 08:17:54.726169: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-04-20 08:17:54.726186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-04-20 08:17:54.727321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.728119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-20 08:17:54.728867: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-20 08:17:54.728919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From train.py:50: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2020-04-20 08:18:00.470747: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-20 08:18:01.898703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 训练100,loss=2.302703380584717,accuracy=0.05
# 测试100,loss=2.304065227508545,accuracy=0.1
# 训练200,loss=2.3002123832702637,accuracy=0.1
# 测试200,loss=2.2818450927734375,accuracy=0.15
# 训练300,loss=2.3613200187683105,accuracy=0.05
# 测试300,loss=2.041667938232422,accuracy=0.2
# 训练400,loss=2.0463249683380127,accuracy=0.2
# 测试400,loss=1.8317315578460693,accuracy=0.5
# 训练500,loss=2.1756324768066406,accuracy=0.05
# 测试500,loss=1.7133830785751343,accuracy=0.35
# 训练600,loss=1.7121015787124634,accuracy=0.45
# 测试600,loss=1.5403212308883667,accuracy=0.6
# 训练700,loss=2.079784393310547,accuracy=0.2
# 测试700,loss=1.546862244606018,accuracy=0.6
# 训练800,loss=1.5349215269088745,accuracy=0.4
# 测试800,loss=1.442439317703247,accuracy=0.45
# 训练900,loss=1.5107016563415527,accuracy=0.4
# 测试900,loss=1.6363742351531982,accuracy=0.5
# 训练1000,loss=1.9433494806289673,accuracy=0.2
# 测试1000,loss=1.4157487154006958,accuracy=0.5
# 训练1100,loss=2.0081920623779297,accuracy=0.3
# 测试1100,loss=1.576770544052124,accuracy=0.45
# 训练1200,loss=2.0503787994384766,accuracy=0.25
# 测试1200,loss=1.55030357837677,accuracy=0.55
# 训练1300,loss=1.8978742361068726,accuracy=0.3
# 测试1300,loss=1.4132684469223022,accuracy=0.5
# 训练1400,loss=1.9323383569717407,accuracy=0.35
# 测试1400,loss=1.580457329750061,accuracy=0.45
# 训练1500,loss=1.6605666875839233,accuracy=0.5
# 测试1500,loss=1.2621409893035889,accuracy=0.6
# 训练1600,loss=1.4296833276748657,accuracy=0.6
# 测试1600,loss=1.301037311553955,accuracy=0.6
# 训练1700,loss=1.7260669469833374,accuracy=0.5
# 测试1700,loss=1.1507601737976074,accuracy=0.55
# 训练1800,loss=1.6844351291656494,accuracy=0.3
# 测试1800,loss=1.5494590997695923,accuracy=0.55
# 训练1900,loss=1.6585537195205688,accuracy=0.4
# 测试1900,loss=1.2751424312591553,accuracy=0.6
# 训练2000,loss=1.9089683294296265,accuracy=0.25
# 测试2000,loss=1.2059910297393799,accuracy=0.55
# 训练2100,loss=1.7786699533462524,accuracy=0.45
# 测试2100,loss=1.0629866123199463,accuracy=0.6
# 训练2200,loss=1.6188323497772217,accuracy=0.5
# 测试2200,loss=1.2997190952301025,accuracy=0.35
# 训练2300,loss=2.0195438861846924,accuracy=0.35
# 测试2300,loss=1.0633060932159424,accuracy=0.6
# 训练2400,loss=1.9526761770248413,accuracy=0.4
# 测试2400,loss=1.1186870336532593,accuracy=0.65
# 训练2500,loss=1.7481390237808228,accuracy=0.5
# 测试2500,loss=1.2326812744140625,accuracy=0.5
# 训练2600,loss=1.421757459640503,accuracy=0.4
# 测试2600,loss=0.9088835716247559,accuracy=0.65
# 训练2700,loss=1.32997465133667,accuracy=0.4
# 测试2700,loss=1.3074891567230225,accuracy=0.45
# 训练2800,loss=1.6050732135772705,accuracy=0.5
# 测试2800,loss=1.1974842548370361,accuracy=0.65
# 训练2900,loss=1.4220283031463623,accuracy=0.4
# 测试2900,loss=1.0813268423080444,accuracy=0.65
# 训练3000,loss=1.3671660423278809,accuracy=0.5
# 测试3000,loss=1.125769019126892,accuracy=0.65
# 训练3100,loss=1.6166954040527344,accuracy=0.25
# 测试3100,loss=0.9306514859199524,accuracy=0.65
# 训练3200,loss=1.185197353363037,accuracy=0.6
# 测试3200,loss=0.9246077537536621,accuracy=0.65
# 训练3300,loss=1.9876296520233154,accuracy=0.3
# 测试3300,loss=0.9217077493667603,accuracy=0.85
# 训练3400,loss=1.3466991186141968,accuracy=0.45
# 测试3400,loss=0.904040515422821,accuracy=0.8
# 训练3500,loss=1.2231028079986572,accuracy=0.55
# 测试3500,loss=1.0032892227172852,accuracy=0.6
# 训练3600,loss=1.5234655141830444,accuracy=0.55
# 测试3600,loss=1.0491583347320557,accuracy=0.65
# 训练3700,loss=1.6216586828231812,accuracy=0.45
# 测试3700,loss=0.9830178022384644,accuracy=0.75
# 训练3800,loss=1.358896255493164,accuracy=0.4
# 测试3800,loss=1.0011215209960938,accuracy=0.65
# 训练3900,loss=1.5762516260147095,accuracy=0.35
# 测试3900,loss=0.9590864181518555,accuracy=0.65
# 训练4000,loss=1.4052999019622803,accuracy=0.6
# 测试4000,loss=0.9469321370124817,accuracy=0.7
# 训练4100,loss=1.1356489658355713,accuracy=0.6
# 测试4100,loss=0.8089604377746582,accuracy=0.8
# 训练4200,loss=1.386755108833313,accuracy=0.45
# 测试4200,loss=0.9397577047348022,accuracy=0.9
# 训练4300,loss=1.3205928802490234,accuracy=0.45
# 测试4300,loss=0.9213167428970337,accuracy=0.8
# 训练4400,loss=1.362573266029358,accuracy=0.55
# 测试4400,loss=0.9305846095085144,accuracy=0.8
# 训练4500,loss=1.2675385475158691,accuracy=0.45
# 测试4500,loss=1.0882799625396729,accuracy=0.65
# 训练4600,loss=1.2756497859954834,accuracy=0.55
# 测试4600,loss=0.7561683654785156,accuracy=0.85
# 训练4700,loss=1.8287906646728516,accuracy=0.4
# 测试4700,loss=1.0325998067855835,accuracy=0.7
# 训练4800,loss=1.6212213039398193,accuracy=0.4
# 测试4800,loss=0.868893027305603,accuracy=0.65
# 训练4900,loss=1.447556495666504,accuracy=0.5
# 测试4900,loss=1.04534912109375,accuracy=0.65
# 训练5000,loss=1.0208088159561157,accuracy=0.75
# 测试5000,loss=0.8428975939750671,accuracy=0.75
# 训练5100,loss=0.7485281825065613,accuracy=0.7
# 测试5100,loss=0.8742347955703735,accuracy=0.8
# 训练5200,loss=1.5695569515228271,accuracy=0.45
# 测试5200,loss=0.890093982219696,accuracy=0.6
# 训练5300,loss=0.8813086748123169,accuracy=0.75
# 测试5300,loss=0.930742084980011,accuracy=0.5
# 训练5400,loss=1.0403276681900024,accuracy=0.6
# 测试5400,loss=0.8351941108703613,accuracy=0.7
# 训练5500,loss=1.3668110370635986,accuracy=0.45
# 测试5500,loss=0.9516143798828125,accuracy=0.6
# 训练5600,loss=1.4344879388809204,accuracy=0.45
# 测试5600,loss=1.1233441829681396,accuracy=0.7
# 训练5700,loss=1.0447864532470703,accuracy=0.6
# 测试5700,loss=0.9172376394271851,accuracy=0.75
# 训练5800,loss=1.4176349639892578,accuracy=0.6
# 测试5800,loss=0.8322799801826477,accuracy=0.85
# 训练5900,loss=1.394108533859253,accuracy=0.5
# 测试5900,loss=0.9528707265853882,accuracy=0.6
# 训练6000,loss=0.9234088659286499,accuracy=0.85
# 测试6000,loss=1.0799580812454224,accuracy=0.5
# 训练6100,loss=1.5034455060958862,accuracy=0.45
# 测试6100,loss=0.7568291425704956,accuracy=0.85
# 训练6200,loss=1.5676002502441406,accuracy=0.45
# 测试6200,loss=0.8919299244880676,accuracy=0.7
# 训练6300,loss=1.29933762550354,accuracy=0.5
# 测试6300,loss=1.2329756021499634,accuracy=0.65
# 训练6400,loss=2.1893811225891113,accuracy=0.3
# 测试6400,loss=1.057122826576233,accuracy=0.65
# 训练6500,loss=1.1215531826019287,accuracy=0.45
# 测试6500,loss=0.8674433827400208,accuracy=0.65
# 训练6600,loss=1.4423906803131104,accuracy=0.35
# 测试6600,loss=0.9893385171890259,accuracy=0.65
# 训练6700,loss=1.1735066175460815,accuracy=0.6
# 测试6700,loss=0.670987606048584,accuracy=0.85
# 训练6800,loss=1.3612663745880127,accuracy=0.5
# 测试6800,loss=1.0387073755264282,accuracy=0.65
# 训练6900,loss=0.9047868847846985,accuracy=0.75
# 测试6900,loss=1.0802212953567505,accuracy=0.6
# 训练7000,loss=1.3254094123840332,accuracy=0.55
# 测试7000,loss=0.7627403736114502,accuracy=0.7
# 训练7100,loss=0.6810225248336792,accuracy=0.75
# 测试7100,loss=0.8958219289779663,accuracy=0.65
# 训练7200,loss=1.0923835039138794,accuracy=0.6
# 测试7200,loss=0.8338350057601929,accuracy=0.75
# 训练7300,loss=0.9506444931030273,accuracy=0.65
# 测试7300,loss=0.9749521017074585,accuracy=0.6
# 训练7400,loss=1.870184302330017,accuracy=0.4
# 测试7400,loss=1.0001344680786133,accuracy=0.65
# 训练7500,loss=0.6673945188522339,accuracy=0.7
# 测试7500,loss=0.862777590751648,accuracy=0.6
# 训练7600,loss=0.7647582292556763,accuracy=0.75
# 测试7600,loss=0.8499043583869934,accuracy=0.65
# 训练7700,loss=1.0707814693450928,accuracy=0.7
# 测试7700,loss=0.7295054197311401,accuracy=0.85
# 训练7800,loss=1.2416326999664307,accuracy=0.55
# 测试7800,loss=0.7245924472808838,accuracy=0.7
# 训练7900,loss=1.531414270401001,accuracy=0.5
# 测试7900,loss=0.9272340536117554,accuracy=0.7
# 训练8000,loss=0.8652403950691223,accuracy=0.65
# 测试8000,loss=0.7296649217605591,accuracy=0.85
# 训练8100,loss=1.2902369499206543,accuracy=0.7
# 测试8100,loss=0.8957287073135376,accuracy=0.85
# 训练8200,loss=1.6356170177459717,accuracy=0.5
# 测试8200,loss=0.8374053835868835,accuracy=0.85
# 训练8300,loss=1.5231316089630127,accuracy=0.5
# 测试8300,loss=0.8708135485649109,accuracy=0.7
# 训练8400,loss=1.0904147624969482,accuracy=0.65
# 测试8400,loss=0.8414440155029297,accuracy=0.65
# 训练8500,loss=0.9964496493339539,accuracy=0.65
# 测试8500,loss=0.856052577495575,accuracy=0.6
# 训练8600,loss=0.9465965032577515,accuracy=0.6
# 测试8600,loss=0.8006461262702942,accuracy=0.65
# 训练8700,loss=1.3105740547180176,accuracy=0.55
# 测试8700,loss=0.75675368309021,accuracy=0.7
# 训练8800,loss=1.3391988277435303,accuracy=0.75
# 测试8800,loss=0.7625845670700073,accuracy=0.7
# 训练8900,loss=0.6453272104263306,accuracy=0.8
# 测试8900,loss=0.8130003213882446,accuracy=0.65
# 训练9000,loss=0.8330188989639282,accuracy=0.65
# 测试9000,loss=0.806614875793457,accuracy=0.7
# 训练9100,loss=1.4957480430603027,accuracy=0.4
# 测试9100,loss=0.9126962423324585,accuracy=0.65
# 训练9200,loss=1.2216393947601318,accuracy=0.6
# 测试9200,loss=0.8748065829277039,accuracy=0.65
# 训练9300,loss=0.77520352602005,accuracy=0.75
# 测试9300,loss=0.759654700756073,accuracy=0.75
# 训练9400,loss=1.5214626789093018,accuracy=0.35
# 测试9400,loss=1.02445650100708,accuracy=0.75
# 训练9500,loss=1.0338863134384155,accuracy=0.65
# 测试9500,loss=0.7863209843635559,accuracy=0.7
# 训练9600,loss=0.929023265838623,accuracy=0.7
# 测试9600,loss=0.9056503176689148,accuracy=0.65
# 训练9700,loss=1.8078619241714478,accuracy=0.45
# 测试9700,loss=0.8498712778091431,accuracy=0.7
# 训练9800,loss=1.6158125400543213,accuracy=0.55
# 测试9800,loss=0.806881308555603,accuracy=0.8
# 训练9900,loss=0.7943695783615112,accuracy=0.65
# 测试9900,loss=0.8906278610229492,accuracy=0.75
# 训练10000,loss=1.2100279331207275,accuracy=0.55
# 测试10000,loss=0.7021645307540894,accuracy=0.75
# 训练10100,loss=0.7099903225898743,accuracy=0.75
# 测试10100,loss=0.5671693682670593,accuracy=0.85
# 训练10200,loss=0.914000391960144,accuracy=0.65
# 测试10200,loss=0.9870006442070007,accuracy=0.7
# 训练10300,loss=1.2952309846878052,accuracy=0.45
# 测试10300,loss=0.7710272073745728,accuracy=0.7
# 训练10400,loss=1.1954559087753296,accuracy=0.55
# 测试10400,loss=0.8939580917358398,accuracy=0.7
# 训练10500,loss=1.5718265771865845,accuracy=0.45
# 测试10500,loss=0.7623459100723267,accuracy=0.65
# 训练10600,loss=0.9813116788864136,accuracy=0.6
# 测试10600,loss=0.7772971987724304,accuracy=0.85
# 训练10700,loss=1.1984456777572632,accuracy=0.65
# 测试10700,loss=0.8394745588302612,accuracy=0.75
# 训练10800,loss=0.7403644323348999,accuracy=0.75
# 测试10800,loss=0.7710126638412476,accuracy=0.75
# 训练10900,loss=1.3167462348937988,accuracy=0.6
# 测试10900,loss=0.8910043835639954,accuracy=0.6
# 训练11000,loss=0.6121609807014465,accuracy=0.8
# 测试11000,loss=0.7109848856925964,accuracy=0.8
# 训练11100,loss=0.9789561033248901,accuracy=0.7
# 测试11100,loss=0.7320340871810913,accuracy=0.7
# 训练11200,loss=1.5786092281341553,accuracy=0.25
# 测试11200,loss=0.9031628370285034,accuracy=0.7
# 训练11300,loss=1.0430822372436523,accuracy=0.5
# 测试11300,loss=0.8231601715087891,accuracy=0.65
# 训练11400,loss=1.0027753114700317,accuracy=0.6
# 测试11400,loss=0.7801553606987,accuracy=0.7
# 训练11500,loss=0.8072341680526733,accuracy=0.65
# 测试11500,loss=0.7785418629646301,accuracy=0.7
# 训练11600,loss=1.3456164598464966,accuracy=0.6
# 测试11600,loss=0.8821839094161987,accuracy=0.7
# 训练11700,loss=1.2521483898162842,accuracy=0.65
# 测试11700,loss=0.8965217471122742,accuracy=0.65
# 训练11800,loss=0.7358315587043762,accuracy=0.85
# 测试11800,loss=0.8638632893562317,accuracy=0.6
# 训练11900,loss=1.1075350046157837,accuracy=0.6
# 测试11900,loss=0.8269573450088501,accuracy=0.75
# 训练12000,loss=1.1201304197311401,accuracy=0.6
# 测试12000,loss=0.8048657178878784,accuracy=0.65
# 训练12100,loss=0.7837273478507996,accuracy=0.75
# 测试12100,loss=0.7848972678184509,accuracy=0.7
# 训练12200,loss=1.0325262546539307,accuracy=0.5
# 测试12200,loss=0.7149481177330017,accuracy=0.75
# 训练12300,loss=0.8108125925064087,accuracy=0.65
# 测试12300,loss=0.7672938108444214,accuracy=0.65
# 训练12400,loss=1.0317176580429077,accuracy=0.6
# 测试12400,loss=0.6075178980827332,accuracy=0.75
# 训练12500,loss=1.0391396284103394,accuracy=0.65
# 测试12500,loss=0.7403278350830078,accuracy=0.7
# 训练12600,loss=0.9625258445739746,accuracy=0.6
# 测试12600,loss=0.8877816200256348,accuracy=0.7
# 训练12700,loss=0.9947664141654968,accuracy=0.7
# 测试12700,loss=0.6798274517059326,accuracy=0.8
# 训练12800,loss=1.3064944744110107,accuracy=0.5
# 测试12800,loss=0.5514979958534241,accuracy=0.9
# 训练12900,loss=0.8591195940971375,accuracy=0.65
# 测试12900,loss=0.680797278881073,accuracy=0.75
# 训练13000,loss=0.9053824543952942,accuracy=0.55
# 测试13000,loss=0.8006323575973511,accuracy=0.75
# 训练13100,loss=1.0055148601531982,accuracy=0.5
# 测试13100,loss=0.565022349357605,accuracy=0.85
# 训练13200,loss=1.1860792636871338,accuracy=0.75
# 测试13200,loss=0.9327982068061829,accuracy=0.65
# 训练13300,loss=0.5296810865402222,accuracy=0.85
# 测试13300,loss=0.7947655916213989,accuracy=0.8
# 训练13400,loss=0.9125162363052368,accuracy=0.7
# 测试13400,loss=0.8348643183708191,accuracy=0.6
# 训练13500,loss=0.9137641191482544,accuracy=0.65
# 测试13500,loss=0.7217839360237122,accuracy=0.75
# 训练13600,loss=1.0971624851226807,accuracy=0.55
# 测试13600,loss=0.9139442443847656,accuracy=0.8
# 训练13700,loss=1.3798120021820068,accuracy=0.5
# 测试13700,loss=0.6824220418930054,accuracy=0.75
# 训练13800,loss=1.0275218486785889,accuracy=0.65
# 测试13800,loss=0.8053600192070007,accuracy=0.75
# 训练13900,loss=1.651919960975647,accuracy=0.4
# 测试13900,loss=0.7243166565895081,accuracy=0.75
# 训练14000,loss=0.855380654335022,accuracy=0.85
# 测试14000,loss=0.7364436388015747,accuracy=0.75
# 训练14100,loss=1.048812985420227,accuracy=0.6
# 测试14100,loss=0.8526252508163452,accuracy=0.6
# 训练14200,loss=1.3290878534317017,accuracy=0.55
# 测试14200,loss=0.5894290804862976,accuracy=0.9
# 训练14300,loss=1.1532044410705566,accuracy=0.6
# 测试14300,loss=0.7357913255691528,accuracy=0.75
# 训练14400,loss=1.6025259494781494,accuracy=0.45
# 测试14400,loss=0.7937117218971252,accuracy=0.8
# 训练14500,loss=0.899035632610321,accuracy=0.75
# 测试14500,loss=0.6479703187942505,accuracy=0.85
# 训练14600,loss=1.1599600315093994,accuracy=0.6
# 测试14600,loss=0.6716587543487549,accuracy=0.8
# 训练14700,loss=1.0240013599395752,accuracy=0.5
# 测试14700,loss=0.509497344493866,accuracy=0.9
# 训练14800,loss=0.9417184591293335,accuracy=0.75
# 测试14800,loss=0.6841368079185486,accuracy=0.8
# 训练14900,loss=1.0347005128860474,accuracy=0.7
# 测试14900,loss=0.746916651725769,accuracy=0.7
# 训练15000,loss=0.6645975112915039,accuracy=0.75
# 测试15000,loss=0.7880330681800842,accuracy=0.8
# 训练15100,loss=0.7529455423355103,accuracy=0.75
# 测试15100,loss=0.943978488445282,accuracy=0.7
# 训练15200,loss=0.5396919250488281,accuracy=0.8
# 测试15200,loss=0.6910765171051025,accuracy=0.85
# 训练15300,loss=0.6472148895263672,accuracy=0.85
# 测试15300,loss=0.756761908531189,accuracy=0.75
# 训练15400,loss=0.9354885220527649,accuracy=0.7
# 测试15400,loss=0.6651480793952942,accuracy=0.85
# 训练15500,loss=0.9988397359848022,accuracy=0.6
# 测试15500,loss=0.7321972250938416,accuracy=0.7
# 训练15600,loss=1.1042344570159912,accuracy=0.5
# 测试15600,loss=0.8793929815292358,accuracy=0.75
# 训练15700,loss=0.8941264152526855,accuracy=0.6
# 测试15700,loss=0.8412541151046753,accuracy=0.7
# 训练15800,loss=1.1826417446136475,accuracy=0.55
# 测试15800,loss=0.8388687372207642,accuracy=0.65
# 训练15900,loss=1.5529042482376099,accuracy=0.45
# 测试15900,loss=0.628337025642395,accuracy=0.8
# 训练16000,loss=0.8062397837638855,accuracy=0.7
# 测试16000,loss=0.7590355277061462,accuracy=0.75
# 训练16100,loss=1.0008361339569092,accuracy=0.55
# 测试16100,loss=0.6889823079109192,accuracy=0.65
# 训练16200,loss=1.1034126281738281,accuracy=0.55
# 测试16200,loss=0.7439085245132446,accuracy=0.75
# 训练16300,loss=1.1612253189086914,accuracy=0.6
# 测试16300,loss=0.675094485282898,accuracy=0.7
# 训练16400,loss=0.9792991876602173,accuracy=0.7
# 测试16400,loss=0.5237654447555542,accuracy=0.8
# 训练16500,loss=0.9622793197631836,accuracy=0.65
# 测试16500,loss=0.5445233583450317,accuracy=0.8
# 训练16600,loss=1.0998207330703735,accuracy=0.6
# 测试16600,loss=0.5681182146072388,accuracy=0.85
# 训练16700,loss=0.8170154690742493,accuracy=0.8
# 测试16700,loss=0.7275559306144714,accuracy=0.8
# 训练16800,loss=1.0267817974090576,accuracy=0.6
# 测试16800,loss=0.8300228118896484,accuracy=0.7
# 训练16900,loss=1.0937103033065796,accuracy=0.5
# 测试16900,loss=0.5926023721694946,accuracy=0.8
# 训练17000,loss=0.8140212893486023,accuracy=0.7
# 测试17000,loss=0.5725486874580383,accuracy=0.8
# 训练17100,loss=1.113635778427124,accuracy=0.5
# 测试17100,loss=0.7227408289909363,accuracy=0.75
# 训练17200,loss=0.7411785125732422,accuracy=0.8
# 测试17200,loss=0.8310340046882629,accuracy=0.7
# 训练17300,loss=1.106457233428955,accuracy=0.65
# 测试17300,loss=0.6819964647293091,accuracy=0.75
# 训练17400,loss=0.9768348932266235,accuracy=0.65
# 测试17400,loss=0.5843362808227539,accuracy=0.8
# 训练17500,loss=0.8423675298690796,accuracy=0.65
# 测试17500,loss=0.8420903086662292,accuracy=0.7
# 训练17600,loss=1.044908881187439,accuracy=0.65
# 测试17600,loss=0.8585130572319031,accuracy=0.7
# 训练17700,loss=0.9130052328109741,accuracy=0.65
# 测试17700,loss=0.6324781775474548,accuracy=0.75
# 训练17800,loss=0.489624559879303,accuracy=0.85
# 测试17800,loss=0.6083616018295288,accuracy=0.85
# 训练17900,loss=0.7802491784095764,accuracy=0.7
# 测试17900,loss=0.7333671450614929,accuracy=0.8
# 训练18000,loss=0.9050992131233215,accuracy=0.75
# 测试18000,loss=0.7584428787231445,accuracy=0.7
# 训练18100,loss=1.2440937757492065,accuracy=0.5
# 测试18100,loss=0.7736402750015259,accuracy=0.75
# 训练18200,loss=0.7625528573989868,accuracy=0.8
# 测试18200,loss=0.8258014917373657,accuracy=0.7
# 训练18300,loss=1.106036901473999,accuracy=0.55
# 测试18300,loss=0.8180917501449585,accuracy=0.75
# 训练18400,loss=0.46873560547828674,accuracy=0.9
# 测试18400,loss=0.8688315153121948,accuracy=0.75
# 训练18500,loss=0.5420248508453369,accuracy=0.85
# 测试18500,loss=0.9861587285995483,accuracy=0.75
# 训练18600,loss=1.3207553625106812,accuracy=0.45
# 测试18600,loss=0.9473329782485962,accuracy=0.7
# 训练18700,loss=0.9539850354194641,accuracy=0.75
# 测试18700,loss=0.7811145186424255,accuracy=0.75
# 训练18800,loss=1.0038793087005615,accuracy=0.6
# 测试18800,loss=0.6807622909545898,accuracy=0.7
# 训练18900,loss=1.1862103939056396,accuracy=0.4
# 测试18900,loss=0.821765124797821,accuracy=0.7
# 训练19000,loss=0.593277096748352,accuracy=0.85
# 测试19000,loss=0.6788498163223267,accuracy=0.75
# 训练19100,loss=0.9799200892448425,accuracy=0.6
# 测试19100,loss=0.7072142362594604,accuracy=0.8
# 训练19200,loss=0.7105703353881836,accuracy=0.75
# 测试19200,loss=0.7473760843276978,accuracy=0.8
# 训练19300,loss=0.9336543083190918,accuracy=0.7
# 测试19300,loss=0.576439619064331,accuracy=0.8
# 训练19400,loss=0.8649164438247681,accuracy=0.65
# 测试19400,loss=0.6132010221481323,accuracy=0.8
# 训练19500,loss=0.8366570472717285,accuracy=0.7
# 测试19500,loss=0.8667589426040649,accuracy=0.85
# 训练19600,loss=0.8061164617538452,accuracy=0.7
# 测试19600,loss=0.664054274559021,accuracy=0.75
# 训练19700,loss=1.4027576446533203,accuracy=0.55
# 测试19700,loss=0.7059520483016968,accuracy=0.8
# 训练19800,loss=0.8859308958053589,accuracy=0.6
# 测试19800,loss=0.7309532165527344,accuracy=0.8
# 训练19900,loss=0.8336187601089478,accuracy=0.7
# 测试19900,loss=0.547601580619812,accuracy=1.0
# 训练20000,loss=0.640600323677063,accuracy=0.75
# 测试20000,loss=0.966227650642395,accuracy=0.7
# 训练20100,loss=0.8503615260124207,accuracy=0.7
# 测试20100,loss=0.875323474407196,accuracy=0.6
# 训练20200,loss=0.8578492999076843,accuracy=0.7
# 测试20200,loss=0.6945242881774902,accuracy=0.85
# 训练20300,loss=1.1816037893295288,accuracy=0.7
# 测试20300,loss=1.0148652791976929,accuracy=0.65
# 训练20400,loss=1.1080732345581055,accuracy=0.7
# 测试20400,loss=0.9112037420272827,accuracy=0.65
# 训练20500,loss=1.5923099517822266,accuracy=0.45
# 测试20500,loss=0.7218872308731079,accuracy=0.7
# 训练20600,loss=1.0595194101333618,accuracy=0.7
# 测试20600,loss=0.8114469647407532,accuracy=0.75
# 训练20700,loss=1.1354129314422607,accuracy=0.5
# 测试20700,loss=0.555466890335083,accuracy=0.85
# 训练20800,loss=0.7801697850227356,accuracy=0.7
# 测试20800,loss=0.6631932258605957,accuracy=0.8
# 训练20900,loss=0.7747864723205566,accuracy=0.65
# 测试20900,loss=0.546679675579071,accuracy=0.8
# 训练21000,loss=0.7725357413291931,accuracy=0.7
# 测试21000,loss=0.7782019376754761,accuracy=0.75
# 训练21100,loss=1.094846487045288,accuracy=0.55
# 测试21100,loss=0.7030555009841919,accuracy=0.8
# 训练21200,loss=1.021036982536316,accuracy=0.6
# 测试21200,loss=0.7377554774284363,accuracy=0.8
# 训练21300,loss=1.2405484914779663,accuracy=0.55
# 测试21300,loss=0.7253023386001587,accuracy=0.85
# 训练21400,loss=0.7557124495506287,accuracy=0.65
# 测试21400,loss=0.8349965810775757,accuracy=0.7
# 训练21500,loss=1.304190993309021,accuracy=0.55
# 测试21500,loss=0.8549699783325195,accuracy=0.7
# 训练21600,loss=0.9683386087417603,accuracy=0.65
# 测试21600,loss=0.7584392428398132,accuracy=0.75
# 训练21700,loss=0.934532642364502,accuracy=0.65
# 测试21700,loss=0.702823281288147,accuracy=0.85
# 训练21800,loss=1.5415202379226685,accuracy=0.45
# 测试21800,loss=0.6292966604232788,accuracy=0.75
# 训练21900,loss=0.7749221324920654,accuracy=0.7
# 测试21900,loss=0.7112166285514832,accuracy=0.8
# 训练22000,loss=0.8590764999389648,accuracy=0.65
# 测试22000,loss=0.6325168609619141,accuracy=0.8
# 训练22100,loss=0.928118884563446,accuracy=0.6
# 测试22100,loss=0.6262622475624084,accuracy=0.8
# 训练22200,loss=0.8646033406257629,accuracy=0.65
# 测试22200,loss=0.5698124766349792,accuracy=0.9
# 训练22300,loss=0.567482590675354,accuracy=0.75
# 测试22300,loss=0.5965763330459595,accuracy=0.8
# 训练22400,loss=0.616509735584259,accuracy=0.75
# 测试22400,loss=0.8352111577987671,accuracy=0.7
# 训练22500,loss=1.3345954418182373,accuracy=0.5
# 测试22500,loss=0.7229040265083313,accuracy=0.8
# 训练22600,loss=1.0062772035598755,accuracy=0.6
# 测试22600,loss=0.6584582328796387,accuracy=0.75
# 训练22700,loss=0.6067341566085815,accuracy=0.8
# 测试22700,loss=0.6230279207229614,accuracy=0.85
# 训练22800,loss=0.8201885223388672,accuracy=0.75
# 测试22800,loss=0.8733757734298706,accuracy=0.65
# 训练22900,loss=0.7202291488647461,accuracy=0.75
# 测试22900,loss=0.6570397615432739,accuracy=0.8
# 训练23000,loss=0.5871117115020752,accuracy=0.8
# 测试23000,loss=0.8314433097839355,accuracy=0.65
# 训练23100,loss=0.778117299079895,accuracy=0.55
# 测试23100,loss=0.6310296058654785,accuracy=0.75
# 训练23200,loss=0.642951488494873,accuracy=0.8
# 测试23200,loss=0.6893061995506287,accuracy=0.7
# 训练23300,loss=0.7815250158309937,accuracy=0.75
# 测试23300,loss=0.8724284172058105,accuracy=0.7
# 训练23400,loss=1.1612180471420288,accuracy=0.65
# 测试23400,loss=0.608657956123352,accuracy=0.8
# 训练23500,loss=1.0742132663726807,accuracy=0.65
# 测试23500,loss=0.8329097032546997,accuracy=0.75
# 训练23600,loss=0.9100392460823059,accuracy=0.75
# 测试23600,loss=0.7600531578063965,accuracy=0.7
# 训练23700,loss=0.9385517239570618,accuracy=0.65
# 测试23700,loss=0.8234969973564148,accuracy=0.7
# 训练23800,loss=0.7075082063674927,accuracy=0.7
# 测试23800,loss=0.5759973526000977,accuracy=0.85
# 训练23900,loss=0.518305242061615,accuracy=0.9
# 测试23900,loss=0.5449090003967285,accuracy=0.85
# 训练24000,loss=0.6097102761268616,accuracy=0.75
# 测试24000,loss=0.7888374924659729,accuracy=0.75
# 训练24100,loss=0.7560672163963318,accuracy=0.7
# 测试24100,loss=0.5973860025405884,accuracy=0.8
# 训练24200,loss=0.6441810727119446,accuracy=0.8
# 测试24200,loss=0.5510115623474121,accuracy=0.85
# 训练24300,loss=1.1283464431762695,accuracy=0.65
# 测试24300,loss=0.7464027404785156,accuracy=0.7
# 训练24400,loss=0.8133492469787598,accuracy=0.7
# 测试24400,loss=0.6427407264709473,accuracy=0.75
# 训练24500,loss=0.8371478319168091,accuracy=0.85
# 测试24500,loss=0.6305358409881592,accuracy=0.8
# 训练24600,loss=0.7690613865852356,accuracy=0.75
# 测试24600,loss=0.6872783899307251,accuracy=0.8
# 训练24700,loss=0.6779831051826477,accuracy=0.75
# 测试24700,loss=0.8599643707275391,accuracy=0.8
# 训练24800,loss=1.133591890335083,accuracy=0.6
# 测试24800,loss=0.8099877238273621,accuracy=0.65
# 训练24900,loss=0.8885146975517273,accuracy=0.65
# 测试24900,loss=0.7598167657852173,accuracy=0.7
# 训练25000,loss=0.8308752179145813,accuracy=0.65
# 测试25000,loss=0.9956469535827637,accuracy=0.6
# 训练25100,loss=0.8728063702583313,accuracy=0.65
# 测试25100,loss=0.833760142326355,accuracy=0.75
# 训练25200,loss=0.8300159573554993,accuracy=0.8
# 测试25200,loss=0.543347179889679,accuracy=0.85
# 训练25300,loss=0.8929266929626465,accuracy=0.6
# 测试25300,loss=0.7452859878540039,accuracy=0.75
# 训练25400,loss=1.1660009622573853,accuracy=0.65
# 测试25400,loss=0.5314556956291199,accuracy=0.85
# 训练25500,loss=1.3446877002716064,accuracy=0.55
# 测试25500,loss=0.6009308099746704,accuracy=0.8
# 训练25600,loss=0.576708197593689,accuracy=0.8
# 测试25600,loss=0.9532828330993652,accuracy=0.65
# 训练25700,loss=1.0541146993637085,accuracy=0.65
# 测试25700,loss=0.7172189950942993,accuracy=0.75
# 训练25800,loss=0.7956300973892212,accuracy=0.75
# 测试25800,loss=0.7078049182891846,accuracy=0.7
# 训练25900,loss=0.7733860015869141,accuracy=0.75
# 测试25900,loss=0.755323052406311,accuracy=0.75
# 训练26000,loss=0.7718079686164856,accuracy=0.65
# 测试26000,loss=0.5801362991333008,accuracy=0.85
# 训练26100,loss=1.260350227355957,accuracy=0.55
# 测试26100,loss=0.501889169216156,accuracy=0.9
# 训练26200,loss=0.7602494955062866,accuracy=0.75
# 测试26200,loss=0.7285737991333008,accuracy=0.8
# 训练26300,loss=0.8121183514595032,accuracy=0.65
# 测试26300,loss=0.7035034894943237,accuracy=0.8
# 训练26400,loss=1.0276069641113281,accuracy=0.65
# 测试26400,loss=0.8710096478462219,accuracy=0.65
# 训练26500,loss=0.7904554605484009,accuracy=0.7
# 测试26500,loss=0.5589438080787659,accuracy=0.8
# 训练26600,loss=1.3685634136199951,accuracy=0.5
# 测试26600,loss=0.6463122963905334,accuracy=0.75
# 训练26700,loss=0.8902423977851868,accuracy=0.65
# 测试26700,loss=0.7242665886878967,accuracy=0.75
# 训练26800,loss=1.2064582109451294,accuracy=0.6
# 测试26800,loss=0.9326232671737671,accuracy=0.65
# 训练26900,loss=1.248788595199585,accuracy=0.6
# 测试26900,loss=0.6319620013237,accuracy=0.9
# 训练27000,loss=0.708550751209259,accuracy=0.8
# 测试27000,loss=0.92706698179245,accuracy=0.6
# 训练27100,loss=0.8917987942695618,accuracy=0.6
# 测试27100,loss=0.701309084892273,accuracy=0.8
# 训练27200,loss=1.3557989597320557,accuracy=0.6
# 测试27200,loss=0.6801616549491882,accuracy=0.75
# 训练27300,loss=0.9553323984146118,accuracy=0.6
# 测试27300,loss=1.1296087503433228,accuracy=0.6
# 训练27400,loss=1.0733728408813477,accuracy=0.6
# 测试27400,loss=0.7535565495491028,accuracy=0.75
# 训练27500,loss=0.7389355301856995,accuracy=0.85
# 测试27500,loss=0.803065299987793,accuracy=0.7
# 训练27600,loss=0.937755286693573,accuracy=0.7
# 测试27600,loss=0.5526500344276428,accuracy=0.85
# 训练27700,loss=0.9341731071472168,accuracy=0.75
# 测试27700,loss=0.935703456401825,accuracy=0.65
# 训练27800,loss=1.0359827280044556,accuracy=0.6
# 测试27800,loss=0.6263983249664307,accuracy=0.85
# 训练27900,loss=0.6112931966781616,accuracy=0.65
# 测试27900,loss=0.5950164794921875,accuracy=0.8
# 训练28000,loss=0.5735772252082825,accuracy=0.8
# 测试28000,loss=0.7488630414009094,accuracy=0.75
# 训练28100,loss=1.073662519454956,accuracy=0.6
# 测试28100,loss=0.5413163304328918,accuracy=0.85
# 训练28200,loss=0.6972665190696716,accuracy=0.75
# 测试28200,loss=0.7417315244674683,accuracy=0.75
# 训练28300,loss=1.0010402202606201,accuracy=0.65
# 测试28300,loss=0.5628635287284851,accuracy=0.75
# 训练28400,loss=1.2194823026657104,accuracy=0.6
# 测试28400,loss=0.48669177293777466,accuracy=0.85
# 训练28500,loss=0.6367948055267334,accuracy=0.7
# 测试28500,loss=0.602303147315979,accuracy=0.8
# 训练28600,loss=1.395707368850708,accuracy=0.55
# 测试28600,loss=0.7508095502853394,accuracy=0.7
# 训练28700,loss=1.0943115949630737,accuracy=0.55
# 测试28700,loss=0.7091888189315796,accuracy=0.6
# 训练28800,loss=1.0848454236984253,accuracy=0.65
# 测试28800,loss=1.0103614330291748,accuracy=0.7
# 训练28900,loss=0.7440381646156311,accuracy=0.7
# 测试28900,loss=0.9427863955497742,accuracy=0.65
# 训练29000,loss=0.6989345550537109,accuracy=0.7
# 测试29000,loss=0.7386068105697632,accuracy=0.85
# 训练29100,loss=0.7810174226760864,accuracy=0.7
# 测试29100,loss=0.9615486860275269,accuracy=0.7
# 训练29200,loss=0.8030179738998413,accuracy=0.55
# 测试29200,loss=0.8575626611709595,accuracy=0.65
# 训练29300,loss=0.7901619672775269,accuracy=0.8
# 测试29300,loss=0.645345151424408,accuracy=0.8
# 训练29400,loss=1.1384470462799072,accuracy=0.6
# 测试29400,loss=0.6168146729469299,accuracy=0.85
# 训练29500,loss=0.6790035963058472,accuracy=0.75
# 测试29500,loss=0.5971365571022034,accuracy=0.8
# 训练29600,loss=1.3480724096298218,accuracy=0.55
# 测试29600,loss=0.631665050983429,accuracy=0.9
# 训练29700,loss=1.0317919254302979,accuracy=0.65
# 测试29700,loss=0.6780939698219299,accuracy=0.8
# 训练29800,loss=0.563048779964447,accuracy=0.8
# 测试29800,loss=0.6304287910461426,accuracy=0.7
# 训练29900,loss=1.2274134159088135,accuracy=0.5
# 测试29900,loss=0.6798909902572632,accuracy=0.8
# 训练30000,loss=1.228996992111206,accuracy=0.55
# 测试30000,loss=0.8995827436447144,accuracy=0.8
# 训练30100,loss=0.9734675288200378,accuracy=0.6
# 测试30100,loss=0.7558440566062927,accuracy=0.8
# 训练30200,loss=0.5526288151741028,accuracy=0.85
# 测试30200,loss=0.6371399164199829,accuracy=0.8
# 训练30300,loss=1.316696286201477,accuracy=0.55
# 测试30300,loss=0.7021291255950928,accuracy=0.85
# 训练30400,loss=1.0667731761932373,accuracy=0.65
# 测试30400,loss=0.8463907241821289,accuracy=0.8
# 训练30500,loss=1.4298069477081299,accuracy=0.5
# 测试30500,loss=0.9527341723442078,accuracy=0.7
# 训练30600,loss=0.6169910430908203,accuracy=0.75
# 测试30600,loss=0.7864736318588257,accuracy=0.75
# 训练30700,loss=0.8330379724502563,accuracy=0.7
# 测试30700,loss=0.801445484161377,accuracy=0.7
# 训练30800,loss=1.0279943943023682,accuracy=0.7
# 测试30800,loss=0.5800546407699585,accuracy=0.85
# 训练30900,loss=1.250457525253296,accuracy=0.6
# 测试30900,loss=0.9088090062141418,accuracy=0.65
# 训练31000,loss=1.0490028858184814,accuracy=0.7
# 测试31000,loss=0.6277442574501038,accuracy=0.75
# 训练31100,loss=0.8045730590820312,accuracy=0.75
# 测试31100,loss=0.8101938366889954,accuracy=0.65
# 训练31200,loss=0.6403145790100098,accuracy=0.75
# 测试31200,loss=0.6212517619132996,accuracy=0.8
# 训练31300,loss=0.8120511174201965,accuracy=0.7
# 测试31300,loss=0.8328105211257935,accuracy=0.8
# 训练31400,loss=0.9935125112533569,accuracy=0.5
# 测试31400,loss=0.7332502603530884,accuracy=0.75
# 训练31500,loss=0.8788213729858398,accuracy=0.7
# 测试31500,loss=0.6622053384780884,accuracy=0.75
# 训练31600,loss=1.0874097347259521,accuracy=0.65
# 测试31600,loss=0.5414933562278748,accuracy=0.9
# 训练31700,loss=1.2428628206253052,accuracy=0.5
# 测试31700,loss=0.7851824164390564,accuracy=0.7
# 训练31800,loss=0.8424892425537109,accuracy=0.75
# 测试31800,loss=0.7369259595870972,accuracy=0.8
# 训练31900,loss=0.9280216097831726,accuracy=0.6
# 测试31900,loss=0.8590397834777832,accuracy=0.6
# 训练32000,loss=1.0609769821166992,accuracy=0.65
# 测试32000,loss=0.7520159482955933,accuracy=0.8
# 训练32100,loss=0.6858202815055847,accuracy=0.8
# 测试32100,loss=0.8451524972915649,accuracy=0.5
# 训练32200,loss=0.8983052968978882,accuracy=0.6
# 测试32200,loss=0.7963136434555054,accuracy=0.65
# 训练32300,loss=0.8691818118095398,accuracy=0.65
# 测试32300,loss=0.5565020442008972,accuracy=0.85
# 训练32400,loss=0.9819222688674927,accuracy=0.65
# 测试32400,loss=0.7458949685096741,accuracy=0.7
# 训练32500,loss=0.6355496048927307,accuracy=0.75
# 测试32500,loss=0.6084995269775391,accuracy=0.8
# 训练32600,loss=1.065063238143921,accuracy=0.6
# 测试32600,loss=0.6556252837181091,accuracy=0.8
# 训练32700,loss=1.1859972476959229,accuracy=0.6
# 测试32700,loss=0.6314328908920288,accuracy=0.8
# 训练32800,loss=0.890515923500061,accuracy=0.8
# 测试32800,loss=0.5456777811050415,accuracy=0.9
# 训练32900,loss=1.2415140867233276,accuracy=0.55
# 测试32900,loss=0.5883916616439819,accuracy=0.85
# 训练33000,loss=1.036517858505249,accuracy=0.55
# 测试33000,loss=0.9848898649215698,accuracy=0.65
# 训练33100,loss=0.9286944270133972,accuracy=0.6
# 测试33100,loss=0.5599647760391235,accuracy=0.85
# 训练33200,loss=1.278997778892517,accuracy=0.55
# 测试33200,loss=0.496736615896225,accuracy=0.9
# 训练33300,loss=0.5596416592597961,accuracy=0.8
# 测试33300,loss=0.6814223527908325,accuracy=0.65
# 训练33400,loss=1.548854947090149,accuracy=0.55
# 测试33400,loss=0.47066956758499146,accuracy=0.8
# 训练33500,loss=0.5015244483947754,accuracy=0.8
# 测试33500,loss=0.7187454700469971,accuracy=0.75
# 训练33600,loss=1.1882798671722412,accuracy=0.55
# 测试33600,loss=0.6349902749061584,accuracy=0.8
# 训练33700,loss=0.9322473406791687,accuracy=0.8
# 测试33700,loss=0.5334185361862183,accuracy=0.8
# 训练33800,loss=0.7937090992927551,accuracy=0.7
# 测试33800,loss=0.7269267439842224,accuracy=0.75
# 训练33900,loss=0.8015974164009094,accuracy=0.7
# 测试33900,loss=0.6427146196365356,accuracy=0.85
# 训练34000,loss=1.1782877445220947,accuracy=0.65
# 测试34000,loss=0.847924530506134,accuracy=0.8
# 训练34100,loss=0.8336882591247559,accuracy=0.75
# 测试34100,loss=0.675801157951355,accuracy=0.8
# 训练34200,loss=0.7696163058280945,accuracy=0.75
# 测试34200,loss=0.7943322658538818,accuracy=0.7
# 训练34300,loss=1.388237476348877,accuracy=0.6
# 测试34300,loss=0.7710034251213074,accuracy=0.7
# 训练34400,loss=0.7120809555053711,accuracy=0.7
# 测试34400,loss=0.780839741230011,accuracy=0.85
# 训练34500,loss=1.3148772716522217,accuracy=0.6
# 测试34500,loss=0.6753786206245422,accuracy=0.65
# 训练34600,loss=1.3636994361877441,accuracy=0.5
# 测试34600,loss=0.6494142413139343,accuracy=0.85
# 训练34700,loss=0.9729880094528198,accuracy=0.6
# 测试34700,loss=0.6913187503814697,accuracy=0.8
# 训练34800,loss=1.7586807012557983,accuracy=0.35
# 测试34800,loss=0.5802925825119019,accuracy=0.8
# 训练34900,loss=1.1001635789871216,accuracy=0.5
# 测试34900,loss=0.540289580821991,accuracy=0.75
# 训练35000,loss=0.7851206660270691,accuracy=0.6
# 测试35000,loss=0.7149308323860168,accuracy=0.85
# 训练35100,loss=0.9479618072509766,accuracy=0.55
# 测试35100,loss=0.6917239427566528,accuracy=0.85
# 训练35200,loss=0.7650067210197449,accuracy=0.7
# 测试35200,loss=0.7237949371337891,accuracy=0.8
# 训练35300,loss=1.0294773578643799,accuracy=0.45
# 测试35300,loss=0.7490087747573853,accuracy=0.7
# 训练35400,loss=0.7335072159767151,accuracy=0.75
# 测试35400,loss=0.6650513410568237,accuracy=0.8
# 训练35500,loss=0.9429861903190613,accuracy=0.7
# 测试35500,loss=0.7082639336585999,accuracy=0.8
# 训练35600,loss=0.7874745726585388,accuracy=0.65
# 测试35600,loss=0.6520962119102478,accuracy=0.8
# 训练35700,loss=0.7717383503913879,accuracy=0.75
# 测试35700,loss=0.6481691598892212,accuracy=0.85
# 训练35800,loss=0.5257532596588135,accuracy=0.9
# 测试35800,loss=0.6218637228012085,accuracy=0.85
# 训练35900,loss=1.121622085571289,accuracy=0.55
# 测试35900,loss=0.6948703527450562,accuracy=0.8
# 训练36000,loss=1.0670661926269531,accuracy=0.65
# 测试36000,loss=0.7093443870544434,accuracy=0.75
# 训练36100,loss=0.9047188758850098,accuracy=0.6
# 测试36100,loss=0.3923482298851013,accuracy=0.9
# 训练36200,loss=1.2857887744903564,accuracy=0.7
# 测试36200,loss=0.5650173425674438,accuracy=0.75
# 训练36300,loss=0.9914404153823853,accuracy=0.6
# 测试36300,loss=0.5831061601638794,accuracy=0.85
# 训练36400,loss=1.1037412881851196,accuracy=0.65
# 测试36400,loss=0.525883138179779,accuracy=0.85
# 训练36500,loss=1.2321932315826416,accuracy=0.6
# 测试36500,loss=0.8037182092666626,accuracy=0.7
# 训练36600,loss=0.5874484181404114,accuracy=0.8
# 测试36600,loss=0.9019126892089844,accuracy=0.75
# 训练36700,loss=0.9687981605529785,accuracy=0.75
# 测试36700,loss=0.6555815935134888,accuracy=0.8
# 训练36800,loss=0.9499098062515259,accuracy=0.75
# 测试36800,loss=0.6405673623085022,accuracy=0.8
# 训练36900,loss=0.8956480026245117,accuracy=0.6
# 测试36900,loss=0.8255382776260376,accuracy=0.75
# 训练37000,loss=0.4874956011772156,accuracy=0.8
# 测试37000,loss=0.507623016834259,accuracy=0.85
# 训练37100,loss=0.8810691833496094,accuracy=0.65
# 测试37100,loss=0.7044996023178101,accuracy=0.8
# 训练37200,loss=0.8924926519393921,accuracy=0.6
# 测试37200,loss=0.622470498085022,accuracy=0.75
# 训练37300,loss=0.8741723299026489,accuracy=0.65
# 测试37300,loss=0.5966683626174927,accuracy=0.75
# 训练37400,loss=1.2994725704193115,accuracy=0.5
# 测试37400,loss=0.8082805871963501,accuracy=0.7
# 训练37500,loss=1.1842707395553589,accuracy=0.6
# 测试37500,loss=0.8114385604858398,accuracy=0.75
# 训练37600,loss=0.8411617279052734,accuracy=0.8
# 测试37600,loss=0.6926001310348511,accuracy=0.85
# 训练37700,loss=0.9963153600692749,accuracy=0.7
# 测试37700,loss=0.7458602786064148,accuracy=0.8
# 训练37800,loss=0.6953763365745544,accuracy=0.75
# 测试37800,loss=0.4715522825717926,accuracy=0.9
# 训练37900,loss=0.9986554980278015,accuracy=0.55
# 测试37900,loss=0.6939971446990967,accuracy=0.75
# 训练38000,loss=0.8431933522224426,accuracy=0.75
# 测试38000,loss=0.739365816116333,accuracy=0.8
# 训练38100,loss=0.9312542080879211,accuracy=0.7
# 测试38100,loss=0.5438024401664734,accuracy=0.8
# 训练38200,loss=0.9583337903022766,accuracy=0.65
# 测试38200,loss=0.6328307390213013,accuracy=0.85
# 训练38300,loss=0.5447143316268921,accuracy=0.8
# 测试38300,loss=0.7025278210639954,accuracy=0.7
# 训练38400,loss=0.6613038778305054,accuracy=0.8
# 测试38400,loss=0.4966183304786682,accuracy=0.9
# 训练38500,loss=0.8160150647163391,accuracy=0.75
# 测试38500,loss=0.7790101766586304,accuracy=0.75
# 训练38600,loss=1.3813940286636353,accuracy=0.5
# 测试38600,loss=0.5814321637153625,accuracy=0.85
# 训练38700,loss=1.0483585596084595,accuracy=0.7
# 测试38700,loss=0.6605798602104187,accuracy=0.8
# 训练38800,loss=0.5783499479293823,accuracy=0.8
# 测试38800,loss=0.666843831539154,accuracy=0.75
# 训练38900,loss=1.118164300918579,accuracy=0.55
# 测试38900,loss=0.754516065120697,accuracy=0.7
# 训练39000,loss=0.6210354566574097,accuracy=0.9
# 测试39000,loss=0.596965491771698,accuracy=0.85
# 训练39100,loss=0.8002432584762573,accuracy=0.65
# 测试39100,loss=0.5133026242256165,accuracy=0.85
# 训练39200,loss=1.234161138534546,accuracy=0.55
# 测试39200,loss=0.7334489226341248,accuracy=0.75
# 训练39300,loss=0.7765456438064575,accuracy=0.75
# 测试39300,loss=0.5295851230621338,accuracy=0.85
# 训练39400,loss=0.6582287549972534,accuracy=0.8
# 测试39400,loss=0.5123999714851379,accuracy=0.9
# 训练39500,loss=1.3237696886062622,accuracy=0.65
# 测试39500,loss=0.8910102844238281,accuracy=0.75
# 训练39600,loss=0.630899965763092,accuracy=0.8
# 测试39600,loss=0.536928117275238,accuracy=0.85
# 训练39700,loss=1.0002928972244263,accuracy=0.75
# 测试39700,loss=0.5925502181053162,accuracy=0.8
# 训练39800,loss=1.425477385520935,accuracy=0.55
# 测试39800,loss=0.5319485664367676,accuracy=0.85
# 训练39900,loss=0.7697683572769165,accuracy=0.75
# 测试39900,loss=0.5604698061943054,accuracy=0.8
# 训练40000,loss=1.1564308404922485,accuracy=0.55
# 测试40000,loss=0.5404318571090698,accuracy=0.8
# 训练40100,loss=0.9390907287597656,accuracy=0.6
# 测试40100,loss=0.641839861869812,accuracy=0.8
# 训练40200,loss=0.9622066617012024,accuracy=0.7
# 测试40200,loss=0.7346779108047485,accuracy=0.75
# 训练40300,loss=0.6426929831504822,accuracy=0.75
# 测试40300,loss=0.7041300535202026,accuracy=0.75
# 训练40400,loss=0.935155987739563,accuracy=0.65
# 测试40400,loss=0.8698927164077759,accuracy=0.8
# 训练40500,loss=0.6231635808944702,accuracy=0.75
# 测试40500,loss=0.6144555807113647,accuracy=0.75
# 训练40600,loss=0.8194171786308289,accuracy=0.7
# 测试40600,loss=0.611589252948761,accuracy=0.8
# 训练40700,loss=1.4483786821365356,accuracy=0.6
# 测试40700,loss=0.5968796014785767,accuracy=0.85
# 训练40800,loss=0.9554641842842102,accuracy=0.65
# 测试40800,loss=0.8800908327102661,accuracy=0.65
# 训练40900,loss=0.7100271582603455,accuracy=0.7
# 测试40900,loss=0.7833527326583862,accuracy=0.75
# 训练41000,loss=1.199577808380127,accuracy=0.65
# 测试41000,loss=0.6930254101753235,accuracy=0.75
# 训练41100,loss=1.0681582689285278,accuracy=0.65
# 测试41100,loss=0.8934291005134583,accuracy=0.7
# 训练41200,loss=0.6693688035011292,accuracy=0.8
# 测试41200,loss=0.5997012853622437,accuracy=0.85
# 训练41300,loss=0.6998241543769836,accuracy=0.75
# 测试41300,loss=0.7179611921310425,accuracy=0.7
# 训练41400,loss=0.6424657702445984,accuracy=0.8
# 测试41400,loss=0.7408009767532349,accuracy=0.8
# 训练41500,loss=0.8329583406448364,accuracy=0.7
# 测试41500,loss=0.6241201758384705,accuracy=0.85
# 训练41600,loss=1.5573618412017822,accuracy=0.3
# 测试41600,loss=0.8649755716323853,accuracy=0.65
# 训练41700,loss=1.2672350406646729,accuracy=0.7
# 测试41700,loss=0.6619806885719299,accuracy=0.8
# 训练41800,loss=1.3198645114898682,accuracy=0.5
# 测试41800,loss=0.7163280248641968,accuracy=0.75
# 训练41900,loss=0.82426917552948,accuracy=0.8
# 测试41900,loss=0.6679176688194275,accuracy=0.75
# 训练42000,loss=1.1282109022140503,accuracy=0.6
# 测试42000,loss=0.6143550276756287,accuracy=0.7
# 训练42100,loss=0.550416111946106,accuracy=0.8
# 测试42100,loss=0.771645724773407,accuracy=0.6
# 训练42200,loss=0.9209443926811218,accuracy=0.8
# 测试42200,loss=0.957426905632019,accuracy=0.65
# 训练42300,loss=0.7523638606071472,accuracy=0.75
# 测试42300,loss=0.7350315451622009,accuracy=0.75
# 训练42400,loss=0.8196679949760437,accuracy=0.75
# 测试42400,loss=0.7503798604011536,accuracy=0.65
# ...
# 训练82500,loss=0.6434096097946167,accuracy=0.8
# 测试82500,loss=0.8243855237960815,accuracy=0.75
# 训练82600,loss=0.7516835927963257,accuracy=0.75
# 测试82600,loss=1.1771321296691895,accuracy=0.7
# 训练82700,loss=0.5377849340438843,accuracy=0.8
# 测试82700,loss=0.8895902633666992,accuracy=0.75
# 训练82800,loss=0.6469591856002808,accuracy=0.65
# 测试82800,loss=0.5889896750450134,accuracy=0.8
# 训练82900,loss=0.5151897668838501,accuracy=0.8
# 测试82900,loss=0.8214103579521179,accuracy=0.75
# 训练83000,loss=0.6491323709487915,accuracy=0.85
# 测试83000,loss=0.7655344605445862,accuracy=0.7
# 训练83100,loss=0.4578796327114105,accuracy=0.85
# 测试83100,loss=0.6905401945114136,accuracy=0.75
# 训练83200,loss=0.4130637049674988,accuracy=0.8
# 测试83200,loss=0.8091868162155151,accuracy=0.8
# 训练83300,loss=0.793938159942627,accuracy=0.75
# 测试83300,loss=0.8523409962654114,accuracy=0.75
# 训练83400,loss=0.7734968662261963,accuracy=0.7
# 测试83400,loss=1.0409324169158936,accuracy=0.65
# 训练83500,loss=0.8486574292182922,accuracy=0.55
# 测试83500,loss=1.080895185470581,accuracy=0.55
# 训练83600,loss=0.43741530179977417,accuracy=0.85
# 测试83600,loss=0.6602381467819214,accuracy=0.75
# 训练83700,loss=0.650972843170166,accuracy=0.7
# 测试83700,loss=0.8007259368896484,accuracy=0.75
# 训练83800,loss=0.5346496105194092,accuracy=0.9
# 测试83800,loss=0.8936586380004883,accuracy=0.7
# 训练83900,loss=1.3150831460952759,accuracy=0.6
# 测试83900,loss=0.9704159498214722,accuracy=0.6
# 训练84000,loss=1.101454257965088,accuracy=0.7
# 测试84000,loss=0.6493085026741028,accuracy=0.8
# 训练84100,loss=0.611497700214386,accuracy=0.8
# 测试84100,loss=0.9687519073486328,accuracy=0.7
# 训练84200,loss=0.596697211265564,accuracy=0.8
# 测试84200,loss=0.8850151896476746,accuracy=0.7
# 训练84300,loss=1.0498292446136475,accuracy=0.65
# 测试84300,loss=0.5736950039863586,accuracy=0.85
# 训练84400,loss=0.33874255418777466,accuracy=0.9
# 测试84400,loss=0.8207830190658569,accuracy=0.7
# 训练84500,loss=0.5063186287879944,accuracy=0.85
# 测试84500,loss=0.899407684803009,accuracy=0.7
# 训练84600,loss=0.5937322378158569,accuracy=0.9
# 测试84600,loss=0.8903234601020813,accuracy=0.7
# 训练84700,loss=1.0289971828460693,accuracy=0.8
# 测试84700,loss=0.8460069894790649,accuracy=0.75
# 训练84800,loss=1.1527838706970215,accuracy=0.65
# 测试84800,loss=1.003282904624939,accuracy=0.7
# 训练84900,loss=0.8949235677719116,accuracy=0.75
# 测试84900,loss=0.7381558418273926,accuracy=0.6
# 训练85000,loss=0.8096073269844055,accuracy=0.8
# 测试85000,loss=0.8600444793701172,accuracy=0.65
# 训练85100,loss=0.5751826763153076,accuracy=0.75
# 测试85100,loss=1.012754201889038,accuracy=0.6
# 训练85200,loss=0.716164231300354,accuracy=0.7
# 测试85200,loss=0.707088828086853,accuracy=0.65
# 训练85300,loss=0.5352328419685364,accuracy=0.8
# 测试85300,loss=0.5316692590713501,accuracy=0.8
# 训练85400,loss=0.5277538895606995,accuracy=0.85
# 测试85400,loss=0.7446178197860718,accuracy=0.8
# 训练85500,loss=0.7083107829093933,accuracy=0.85
# 测试85500,loss=0.6848138570785522,accuracy=0.8
# 训练85600,loss=0.6696823835372925,accuracy=0.85
# 测试85600,loss=0.8591033816337585,accuracy=0.7
# 训练85700,loss=0.3014024794101715,accuracy=0.9
# 测试85700,loss=0.769834041595459,accuracy=0.65
# 训练85800,loss=0.7769991159439087,accuracy=0.7
# 测试85800,loss=0.7325093746185303,accuracy=0.75
# 训练85900,loss=0.43031224608421326,accuracy=0.85
# 测试85900,loss=0.7930443286895752,accuracy=0.75
# 训练86000,loss=0.5485385656356812,accuracy=0.9
# 测试86000,loss=0.7485948801040649,accuracy=0.8
# 训练86100,loss=0.9403258562088013,accuracy=0.65
# 测试86100,loss=0.8453270792961121,accuracy=0.65
# 训练86200,loss=1.1144917011260986,accuracy=0.45
# 测试86200,loss=0.788097620010376,accuracy=0.7
# 训练86300,loss=0.819547176361084,accuracy=0.75
# 测试86300,loss=0.6509513258934021,accuracy=0.7
# 训练86400,loss=1.0693901777267456,accuracy=0.55
# 测试86400,loss=0.4526425302028656,accuracy=0.9
# 训练86500,loss=0.8930357098579407,accuracy=0.6
# 测试86500,loss=0.8211849331855774,accuracy=0.65
# 训练86600,loss=0.7194898724555969,accuracy=0.8
# 测试86600,loss=0.7132723331451416,accuracy=0.75
# 训练86700,loss=1.1786426305770874,accuracy=0.6
# 测试86700,loss=0.6003544926643372,accuracy=0.75
# 训练86800,loss=0.9041568040847778,accuracy=0.7
# 测试86800,loss=0.8154044151306152,accuracy=0.65
# 训练86900,loss=0.6681898236274719,accuracy=0.7
# 测试86900,loss=0.9174222946166992,accuracy=0.75
# 训练87000,loss=0.714633584022522,accuracy=0.75
# 测试87000,loss=1.0500471591949463,accuracy=0.65
# 训练87100,loss=0.9556889533996582,accuracy=0.65
# 测试87100,loss=0.8454022407531738,accuracy=0.65
# 训练87200,loss=1.1196925640106201,accuracy=0.65
# 测试87200,loss=0.6349101066589355,accuracy=0.7
# 训练87300,loss=0.673165500164032,accuracy=0.75
# 测试87300,loss=0.6130844950675964,accuracy=0.75
# 训练87400,loss=0.9963275194168091,accuracy=0.6
# 测试87400,loss=0.4695698320865631,accuracy=0.85
# 训练87500,loss=0.8160822987556458,accuracy=0.75
# 测试87500,loss=0.67021644115448,accuracy=0.7
# 训练87600,loss=0.8532881736755371,accuracy=0.7
# 测试87600,loss=0.9429208636283875,accuracy=0.7
# 训练87700,loss=0.854385495185852,accuracy=0.7
# 测试87700,loss=0.706447958946228,accuracy=0.7
# 训练87800,loss=0.6180335283279419,accuracy=0.75
# 测试87800,loss=0.8168643116950989,accuracy=0.75
# 训练87900,loss=0.8302087783813477,accuracy=0.6
# 测试87900,loss=1.1529909372329712,accuracy=0.55
# 训练88000,loss=1.0810297727584839,accuracy=0.5
# 测试88000,loss=0.7776163816452026,accuracy=0.8
# 训练88100,loss=0.8723617792129517,accuracy=0.7
# 测试88100,loss=0.8968842625617981,accuracy=0.7
# 训练88200,loss=0.855023205280304,accuracy=0.7
# 测试88200,loss=0.7243810892105103,accuracy=0.8
# 训练88300,loss=0.7317291498184204,accuracy=0.8
# 测试88300,loss=0.7474780678749084,accuracy=0.7
# 训练88400,loss=0.27333128452301025,accuracy=0.95
# 测试88400,loss=0.7174066305160522,accuracy=0.65
# 训练88500,loss=0.8112202882766724,accuracy=0.6
# 测试88500,loss=0.8015233874320984,accuracy=0.7
# 训练88600,loss=0.5156905651092529,accuracy=0.85
# 测试88600,loss=1.1302648782730103,accuracy=0.65
# 训练88700,loss=0.9141813516616821,accuracy=0.65
# 测试88700,loss=0.6633427739143372,accuracy=0.8
# 训练88800,loss=0.9374068379402161,accuracy=0.6
# 测试88800,loss=0.9136620759963989,accuracy=0.65
# 训练88900,loss=1.1271497011184692,accuracy=0.55
# 测试88900,loss=0.9772588610649109,accuracy=0.7
# 训练89000,loss=0.7059038877487183,accuracy=0.75
# 测试89000,loss=0.6687995791435242,accuracy=0.85
# 训练89100,loss=0.6155242323875427,accuracy=0.85
# 测试89100,loss=1.0311132669448853,accuracy=0.65
# 训练89200,loss=0.6775182485580444,accuracy=0.7
# 测试89200,loss=0.8784282803535461,accuracy=0.65
# 训练89300,loss=0.8140350580215454,accuracy=0.6
# 测试89300,loss=0.9744756817817688,accuracy=0.65
# 训练89400,loss=1.207600712776184,accuracy=0.6
# 测试89400,loss=0.7771257162094116,accuracy=0.8
# 训练89500,loss=0.597538411617279,accuracy=0.8
# 测试89500,loss=0.870935320854187,accuracy=0.75
# 训练89600,loss=0.49524226784706116,accuracy=0.8
# 测试89600,loss=0.9407949447631836,accuracy=0.7
# 训练89700,loss=1.0531896352767944,accuracy=0.55
# 测试89700,loss=0.860678493976593,accuracy=0.75
# 训练89800,loss=0.9953895807266235,accuracy=0.6
# 测试89800,loss=0.9365192651748657,accuracy=0.65
# 训练89900,loss=0.5812098383903503,accuracy=0.75
# 测试89900,loss=0.7223057746887207,accuracy=0.75
# 训练90000,loss=0.7783144116401672,accuracy=0.75
# 测试90000,loss=0.9222432971000671,accuracy=0.65
# 训练90100,loss=0.6587356328964233,accuracy=0.85
# 测试90100,loss=0.6818086504936218,accuracy=0.85
# 训练90200,loss=0.7575458288192749,accuracy=0.6
# 测试90200,loss=0.6691737771034241,accuracy=0.75
# 训练90300,loss=0.8384855389595032,accuracy=0.75
# 测试90300,loss=0.6485556364059448,accuracy=0.7
# 训练90400,loss=0.7457226514816284,accuracy=0.8
# 测试90400,loss=0.7949663996696472,accuracy=0.7
# 训练90500,loss=0.23840327560901642,accuracy=1.0
# 测试90500,loss=0.6943012475967407,accuracy=0.75
# 训练90600,loss=0.6890252828598022,accuracy=0.7
# 测试90600,loss=0.6428647041320801,accuracy=0.8
# 训练90700,loss=0.7564793825149536,accuracy=0.75
# 测试90700,loss=1.135986089706421,accuracy=0.6
# 训练90800,loss=0.896801769733429,accuracy=0.6
# 测试90800,loss=0.8113723993301392,accuracy=0.65
# 训练90900,loss=0.7499743700027466,accuracy=0.7
# 测试90900,loss=0.7728919982910156,accuracy=0.75
# 训练91000,loss=0.6537030339241028,accuracy=0.75
# 测试91000,loss=0.8028852343559265,accuracy=0.65
# 训练91100,loss=0.8597124814987183,accuracy=0.7
# 测试91100,loss=1.1291310787200928,accuracy=0.6
# 训练91200,loss=0.6397989392280579,accuracy=0.85
# 测试91200,loss=0.7946895956993103,accuracy=0.75
# 训练91300,loss=0.5874231457710266,accuracy=0.8
# 测试91300,loss=0.808634877204895,accuracy=0.75
# 训练91400,loss=1.0559768676757812,accuracy=0.6
# 测试91400,loss=0.8785197138786316,accuracy=0.65
# 训练91500,loss=0.4555869698524475,accuracy=0.85
# 测试91500,loss=1.0435943603515625,accuracy=0.6
# 训练91600,loss=0.74127197265625,accuracy=0.75
# 测试91600,loss=0.8063438534736633,accuracy=0.7
# 训练91700,loss=0.8090003728866577,accuracy=0.75
# 测试91700,loss=0.8875612020492554,accuracy=0.7
# 训练91800,loss=1.0609065294265747,accuracy=0.65
# 测试91800,loss=0.805699348449707,accuracy=0.75
# 训练91900,loss=0.7958919405937195,accuracy=0.7
# 测试91900,loss=0.833332359790802,accuracy=0.65
# 训练92000,loss=0.7257945537567139,accuracy=0.75
# 测试92000,loss=0.8604251742362976,accuracy=0.6
# 训练92100,loss=0.5369313955307007,accuracy=0.75
# 测试92100,loss=0.8235293626785278,accuracy=0.65
# 训练92200,loss=0.7331300973892212,accuracy=0.75
# 测试92200,loss=0.4815201163291931,accuracy=0.8
# 训练92300,loss=0.7043535709381104,accuracy=0.65
# 测试92300,loss=0.8811882734298706,accuracy=0.65
# 训练92400,loss=0.6631103754043579,accuracy=0.75
# 测试92400,loss=0.8382493257522583,accuracy=0.7
# 训练92500,loss=0.5612465739250183,accuracy=0.85
# 测试92500,loss=1.2299444675445557,accuracy=0.55
# 训练92600,loss=0.45818549394607544,accuracy=0.8
# 测试92600,loss=0.6957627534866333,accuracy=0.7
# 训练92700,loss=0.5169682502746582,accuracy=0.85
# 测试92700,loss=0.6906813979148865,accuracy=0.7
# 训练92800,loss=1.0726741552352905,accuracy=0.55
# 测试92800,loss=0.8923962712287903,accuracy=0.65
# 训练92900,loss=0.677593469619751,accuracy=0.75
# 测试92900,loss=0.6080117225646973,accuracy=0.8
# 训练93000,loss=0.8362630605697632,accuracy=0.65
# 测试93000,loss=0.8643515706062317,accuracy=0.8
# 训练93100,loss=1.0785435438156128,accuracy=0.6
# 测试93100,loss=0.7709895372390747,accuracy=0.7
# 训练93200,loss=0.6660832762718201,accuracy=0.7
# 测试93200,loss=1.128889799118042,accuracy=0.7
# 训练93300,loss=0.5332762002944946,accuracy=0.8
# 测试93300,loss=0.9124146699905396,accuracy=0.7
# 训练93400,loss=0.7461101412773132,accuracy=0.8
# 测试93400,loss=0.929455578327179,accuracy=0.7
# 训练93500,loss=1.151189923286438,accuracy=0.5
# 测试93500,loss=0.9053703546524048,accuracy=0.6
# 训练93600,loss=0.7639250755310059,accuracy=0.7
# 测试93600,loss=1.0833407640457153,accuracy=0.7
# 训练93700,loss=0.838661789894104,accuracy=0.65
# 测试93700,loss=1.165184736251831,accuracy=0.65
# 训练93800,loss=0.43634194135665894,accuracy=0.85
# 测试93800,loss=0.8592863082885742,accuracy=0.65
# 训练93900,loss=0.9023925065994263,accuracy=0.75
# 测试93900,loss=0.9318714141845703,accuracy=0.7
# 训练94000,loss=0.5480351448059082,accuracy=0.85
# 测试94000,loss=0.638336181640625,accuracy=0.7
# 训练94100,loss=0.6215757131576538,accuracy=0.8
# 测试94100,loss=1.0863791704177856,accuracy=0.7
# 训练94200,loss=0.6525545120239258,accuracy=0.75
# 测试94200,loss=0.866856575012207,accuracy=0.7
# 训练94300,loss=1.0449774265289307,accuracy=0.7
# 测试94300,loss=1.0293527841567993,accuracy=0.65
# 训练94400,loss=0.811429500579834,accuracy=0.75
# 测试94400,loss=0.8293601274490356,accuracy=0.8
# 训练94500,loss=0.7468908429145813,accuracy=0.7
# 测试94500,loss=0.7813295125961304,accuracy=0.75
# 训练94600,loss=0.8356796503067017,accuracy=0.65
# 测试94600,loss=0.9824287295341492,accuracy=0.7
# 训练94700,loss=0.9641548991203308,accuracy=0.6
# 测试94700,loss=1.1351085901260376,accuracy=0.55
# 训练94800,loss=0.9236183166503906,accuracy=0.75
# 测试94800,loss=0.9835823774337769,accuracy=0.6
# 训练94900,loss=0.9094357490539551,accuracy=0.7
# 测试94900,loss=0.9369290471076965,accuracy=0.7
# 训练95000,loss=0.9230454564094543,accuracy=0.7
# 测试95000,loss=0.8775631785392761,accuracy=0.7
# 训练95100,loss=0.5345767140388489,accuracy=0.85
# 测试95100,loss=0.854036808013916,accuracy=0.7
# 训练95200,loss=1.2954809665679932,accuracy=0.55
# 测试95200,loss=0.6746858358383179,accuracy=0.75
# 训练95300,loss=0.9659494161605835,accuracy=0.7
# 测试95300,loss=0.8010735511779785,accuracy=0.65
# 训练95400,loss=0.8994253873825073,accuracy=0.65
# 测试95400,loss=0.8789783716201782,accuracy=0.7
# 训练95500,loss=0.8156998753547668,accuracy=0.8
# 测试95500,loss=0.6773937940597534,accuracy=0.75
# 训练95600,loss=0.7349720597267151,accuracy=0.7
# 测试95600,loss=0.8843655586242676,accuracy=0.65
# 训练95700,loss=0.8187412023544312,accuracy=0.65
# 测试95700,loss=0.8014728426933289,accuracy=0.75
# 训练95800,loss=0.6289559006690979,accuracy=0.75
# 测试95800,loss=0.6548227071762085,accuracy=0.8
# 训练95900,loss=0.451682984828949,accuracy=0.85
# 测试95900,loss=0.7511927485466003,accuracy=0.7
# 训练96000,loss=1.059945821762085,accuracy=0.55
# 测试96000,loss=0.6812609434127808,accuracy=0.65
# 训练96100,loss=1.2694976329803467,accuracy=0.7
# 测试96100,loss=0.8102424740791321,accuracy=0.65
# 训练96200,loss=0.9033424258232117,accuracy=0.7
# 测试96200,loss=0.6347276568412781,accuracy=0.8
# 训练96300,loss=0.4368847906589508,accuracy=0.9
# 测试96300,loss=0.7860242128372192,accuracy=0.7
# 训练96400,loss=0.9468187093734741,accuracy=0.65
# 测试96400,loss=0.8877474665641785,accuracy=0.7
# 训练96500,loss=0.6849347949028015,accuracy=0.85
# 测试96500,loss=0.992865264415741,accuracy=0.6
# 训练96600,loss=0.36796295642852783,accuracy=0.85
# 测试96600,loss=0.8616009950637817,accuracy=0.7
# 训练96700,loss=0.6687396764755249,accuracy=0.7
# 测试96700,loss=0.8781339526176453,accuracy=0.75
# 训练96800,loss=0.5128117799758911,accuracy=0.85
# 测试96800,loss=0.8261467814445496,accuracy=0.65
# 训练96900,loss=0.9397405385971069,accuracy=0.6
# 测试96900,loss=0.6564115881919861,accuracy=0.75
# 训练97000,loss=0.7704071998596191,accuracy=0.8
# 测试97000,loss=0.751329243183136,accuracy=0.6
# 训练97100,loss=0.41749200224876404,accuracy=0.85
# 测试97100,loss=0.739841103553772,accuracy=0.7
# 训练97200,loss=0.8208293914794922,accuracy=0.7
# 测试97200,loss=0.7811554074287415,accuracy=0.75
# 训练97300,loss=0.8516075015068054,accuracy=0.7
# 测试97300,loss=0.7259824872016907,accuracy=0.7
# 训练97400,loss=0.4203869700431824,accuracy=0.9
# 测试97400,loss=0.7217565178871155,accuracy=0.75
# 训练97500,loss=0.7421938180923462,accuracy=0.75
# 测试97500,loss=0.758673369884491,accuracy=0.85
# 训练97600,loss=0.46761804819107056,accuracy=0.75
# 测试97600,loss=0.6990689039230347,accuracy=0.75
# 训练97700,loss=0.7380703687667847,accuracy=0.75
# 测试97700,loss=0.8282338976860046,accuracy=0.75
# 训练97800,loss=0.4888509213924408,accuracy=0.8
# 测试97800,loss=0.6269704103469849,accuracy=0.7
# 训练97900,loss=0.8233597874641418,accuracy=0.7
# 测试97900,loss=0.7494839429855347,accuracy=0.6
# 训练98000,loss=0.8442205190658569,accuracy=0.8
# 测试98000,loss=0.7998393774032593,accuracy=0.7
# 训练98100,loss=0.5336607694625854,accuracy=0.85
# 测试98100,loss=0.7440346479415894,accuracy=0.8
# 训练98200,loss=0.6266864538192749,accuracy=0.8
# 测试98200,loss=0.6866808533668518,accuracy=0.8
# 训练98300,loss=1.0695126056671143,accuracy=0.55
# 测试98300,loss=0.8642122149467468,accuracy=0.65
# 训练98400,loss=0.4517638087272644,accuracy=0.75
# 测试98400,loss=0.6765028834342957,accuracy=0.75
# 训练98500,loss=0.7488763928413391,accuracy=0.7
# 测试98500,loss=0.6739761233329773,accuracy=0.7
# 训练98600,loss=0.8077419996261597,accuracy=0.8
# 测试98600,loss=0.8002422451972961,accuracy=0.8
# 训练98700,loss=0.47514471411705017,accuracy=0.85
# 测试98700,loss=0.5283821821212769,accuracy=0.9
# 训练98800,loss=0.9163142442703247,accuracy=0.65
# 测试98800,loss=0.8370375633239746,accuracy=0.7
# 训练98900,loss=0.6955914497375488,accuracy=0.7
# 测试98900,loss=0.6034143567085266,accuracy=0.65
# 训练99000,loss=0.7531238794326782,accuracy=0.75
# 测试99000,loss=1.027324914932251,accuracy=0.65
# 训练99100,loss=0.8321720361709595,accuracy=0.65
# 测试99100,loss=0.6456758975982666,accuracy=0.75
# 训练99200,loss=1.024261713027954,accuracy=0.8
# 测试99200,loss=0.6765386462211609,accuracy=0.8
# 训练99300,loss=0.8760949969291687,accuracy=0.7
# 测试99300,loss=0.9595581293106079,accuracy=0.6
# 训练99400,loss=0.499986469745636,accuracy=0.85
# 测试99400,loss=0.7616463899612427,accuracy=0.7
# 训练99500,loss=0.5291829109191895,accuracy=0.85
# 测试99500,loss=0.6907962560653687,accuracy=0.85
# 训练99600,loss=0.8430266380310059,accuracy=0.7
# 测试99600,loss=0.5866183042526245,accuracy=0.8
# 训练99700,loss=0.5582402944564819,accuracy=0.8
# 测试99700,loss=0.6384549140930176,accuracy=0.85
# 训练99800,loss=0.8265474438667297,accuracy=0.65
# 测试99800,loss=0.8408352136611938,accuracy=0.65
# 训练99900,loss=0.5463306307792664,accuracy=0.8
# 测试99900,loss=0.565995991230011,accuracy=0.8
# 训练100000,loss=0.8722209930419922,accuracy=0.6
# 测试100000,loss=0.604830265045166,accuracy=0.9

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2020-04-20 08:38:03--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.70.214.4, 35.172.19.128, 52.54.211.101, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.70.214.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  5.88MB/s    in 2.2s
#
# 2020-04-20 08:38:06 (5.88 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# %cd /content/gdrive/My Drive/tensorFlow/cifar10/runTime
LOG_DIR = "./train:'train',./test:'test'"
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# /content/gdrive/My Drive/tensorFlow/cifar10/runTime
# https://ce424790.ngrok.io
